# %% [markdown]
# **Comments meeting:**
# - 17:28:23 From Zeng Ren To Everyone : |density(Note1)-density(Note2)| is a monotinuc with distance_{circle of fifth}(Note1,Note2)
# - 17:28:42 From Zeng Ren To Everyone : my intuition on when the area is maximized
# - 17:29:36 From Robert Lieck To Everyone : yeah, my thinking goes along the same lines...you could then even add other distance metrics
# - 17:30:05 From Robert Lieck To Everyone : this might be a way to get a theoretically well-grounded measure that still captures the same intuitions of the area
# - 17:31:22 From Robert Lieck To Everyone : something like sum p(n1)*p(n2)*1/d(n1,n2) for notes n1 and n2 with probability p(ni) and distance metric d(n1, n2)
# - 17:34:47 From Zeng Ren To Everyone : I think this area induces as “clustering based on density”. in other words, the circle of fifth arrangement coincide with with clustering based on pc density?

# %% [markdown]
# $$A = \sum_{i,j=0}^{11} \frac{p_i p_j}{d_\chi(i,j)d_\phi(i,j)}$$

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import entropy
from scipy.spatial.distance import jensenshannon

from utils import get_polygon, pcs, plot_area, plot_both_areas, tpc2npc, plot_pc_dist, calculate_features

DPI=150 ## for notebook, increase for publication or use PDF
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def PolyArea(p,q):
    """https://stackoverflow.com/questions/24467972/calculate-area-of-polygon-given-x-y-coordinates"""
    return np.abs(np.dot(p,np.roll(q,1)) - np.dot(q,np.roll(p,1))) / 2


def hellinger_distance(p, q):
    return 1 - np.sum([np.sqrt(p_i * q_i) for p_i, q_i in zip(p, q)])


def fifths_area(dist_in_chromatic_order: int, distance_type: str = "geometric") -> float:
    angles = [n / float(12) * 2 * np.pi for n in range(12)]
    fifths_order = [ k * 7 % 12 for k in range(12) ]
    piece = dist_in_chromatic_order.reindex(fifths_order)
    piece /= piece.sum()
    x = piece.values * np.cos(angles)
    x = np.append(x,x[0])
    y = piece.values * np.sin(angles)
    y = np.append(y,y[0])

    if distance_type == "geometric":
        return PolyArea(x,y)
    elif distance_type == "hellinger":
        return hellinger_distance(x,y)
    elif distance == "JS":
        return jensenshannon(p, q)
        

def chromatic_area(dist_in_chromatic_order: int, distance_type: str = "geometric") -> float:
    angles = [n / float(12) * 2 * np.pi for n in range(12)]
    piece = dist_in_chromatic_order
    piece /= piece.sum()
    x = piece.values * np.cos(angles)
    x = np.append(x,x[0])
    y = piece.values * np.sin(angles)
    y = np.append(y,y[0])

    if distance_type == "geometric":
        return PolyArea(x,y)
    elif distance_type == "hellinger":
        return hellinger_distance(x, y)

# %%
import numpy as np
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance


class PcDist:
    """
    Probability distribution on Z_12.
    """

    N = 12

    def __init__(self, probs):
        probs = np.asarray(probs, dtype=float)

        if probs.shape != (self.N,):
            raise ValueError("Distribution must have length 12.")

        if np.any(probs < 0):
            raise ValueError("Probabilities must be nonnegative.")

        total = probs.sum()

        if total <= 0:
            raise ValueError("Probability mass must be positive.")

        self.p = probs / total

    def __repr__(self):
        return f"PcDist({self.p})"

    # ---------------------------------------------------------
    # Information-theoretic distances
    # ---------------------------------------------------------

    def js_distance(self, other):
        """
        Jensen-Shannon distance.
        sqrt(JS divergence).
        """
        return jensenshannon(self.p, other.p)

    def hellinger_distance(self, other):
        """
        Hellinger distance.
        """
        return np.linalg.norm(
            np.sqrt(self.p) - np.sqrt(other.p)
        ) / np.sqrt(2)

    def total_variation(self, other):
        """
        Total variation distance.
        """
        return 0.5 * np.sum(np.abs(self.p - other.p))

    # ---------------------------------------------------------
    # Circular geometry
    # ---------------------------------------------------------

    @staticmethod
    def circular_distance(i, j):
        """
        Distance on Z_12.
        """
        d = abs(i - j)
        return min(d, 12 - d)

    def circular_wasserstein(self, other):
        """
        Approximate circular Wasserstein distance.
        """

        positions = np.arange(12)

        best = np.inf

        # Try all circular shifts
        for shift in range(12):
            shifted = np.roll(other.p, shift)

            w = wasserstein_distance(
                positions,
                positions,
                u_weights=self.p,
                v_weights=shifted
            )

            best = min(best, w)

        return best

    # ---------------------------------------------------------
    # Circular statistics
    # ---------------------------------------------------------

    def circular_mean(self):
        """
        Mean angle on the circle.
        """

        angles = 2 * np.pi * np.arange(12) / 12

        z = np.sum(self.p * np.exp(1j * angles))

        return np.angle(z)

    def concentration(self):
        """
        Circular concentration.
        """

        angles = 2 * np.pi * np.arange(12) / 12

        z = np.sum(self.p * np.exp(1j * angles))

        return np.abs(z)

# %% [markdown]
# ![Exploring](img/exploring_pc_dists.png)

# %%
url = "https://raw.githubusercontent.com/DCMLab/HistoryOfModes/refs/heads/master/templates.csv?token=GHSAT0AAAAAADZTCIT3R3RTV7R7ROKYLTYQ2P5TKPA"
templates = pd.read_csv(url)
templates.to_csv("data/templates.csv", index=False)
templates = pd.read_csv("data/templates.csv")
templates.columns = ["source", "mode"] + [k for k in range(12)]

# %%
fig = plot_both_areas(2,data=templates, fill=True)

# %%
for i in [8, 637, 1658, 2005]: # test pieces
    p = PcDist(pc_freqs.iloc[i,:].values)
    q = PcDist(pc_freqs.iloc[i,:].values * 7 % 12 )
    
    print("===", i, "===")
    print(p.circular_wasserstein(q))
    print(p.hellinger_distance(q))
    print(p.js_distance(q))
    print(p.total_variation(q))
    print("---------------")
# Out:
# === 8 ===
# 2.498001805406602e-16
# 5.887846720064156e-17
# 3.4846899907793303e-09
# 5.0306980803327406e-17
# ---------------
# === 637 ===
# 6.418476861114186e-16
# 8.326672684688673e-17
# nan
# 5.551115123125783e-17
# ---------------
# === 1658 ===
# 3.122502256758253e-16
# 7.076311083754595e-17
# 5.890201144234053e-09
# 1.1275702593849246e-16
# ---------------
# === 2005 ===
# 0.0
# 0.0
# 0.0
# 0.0
# ---------------

# %% [markdown]
# ### Get and preprocess data

# %%
# tp3c = pd.read_csv("https://raw.githubusercontent.com/DCMLab/TP3C/master/tp3c.tsv", sep="\t")
# tp3c.to_csv("data/tp3c.csv", index=False)

# %%
tp3c = pd.read_csv("data/tp3c.csv")

# %%
tp3c = tp3c.sort_values(by="display_year").reset_index(drop=True)

# %%
tp3c = tp3c[["composer", "composer_first", "opus", "no", "mov", "title", "display_year", 'Fbb', 'Cbb', 'Gbb', 'Dbb', 'Abb', 'Ebb', 'Bbb', 'Fb',
       'Cb', 'Gb', 'Db', 'Ab', 'Eb', 'Bb', 'F', 'C', 'G', 'D', 'A', 'E', 'B',
       'F#', 'C#', 'G#', 'D#', 'A#', 'E#', 'B#', 'F##', 'C##', 'G##', 'D##',
       'A##', 'E##', 'B##']]

# %%
# create npc columns
for i in range(12):
    tp3c.loc[:,i] = 0

# %%
# iterate over tpc columns and add to npc cols
for col in ['Fbb', 'Cbb', 'Gbb', 'Dbb', 'Abb', 'Ebb', 'Bbb', 'Fb',
       'Cb', 'Gb', 'Db', 'Ab', 'Eb', 'Bb', 'F', 'C', 'G', 'D', 'A', 'E', 'B',
       'F#', 'C#', 'G#', 'D#', 'A#', 'E#', 'B#', 'F##', 'C##', 'G##', 'D##',
       'A##', 'E##', 'B##']:
    tp3c[tpc2npc(col)] += tp3c[col]

# %%
tp3c.head()
# Out:
#   composer composer_first opus   no  mov                         title  \
# 0    Vitry     Philippede  NaN  NaN  NaN   Gratissima virginis species
# 1    Vitry     Philippede  NaN  NaN  NaN           Lugentium siccentur
# 2    Vitry     Philippede  NaN  NaN  NaN         Virtutibus laudabilis
# 3    Vitry     Philippede  NaN  NaN  NaN             Rex quem metrorum
# 4  Machaut   Guillaume de  NaN  NaN  NaN  Messe de Nostre Dame - Kyrie
#
#    display_year  Fbb  Cbb  Gbb  ...    2  3    4    5   6    7  8    9  10  \
# 0        1361.0    0    0    0  ...  122  0  103  159   0  117  0  133  17
# 1        1361.0    0    0    0  ...  128  0  145  288   2  390  0  367  83
# 2        1361.0    0    0    0  ...   93  0  111  151   3  139  2  182  54
# 3        1361.0    0    0    0  ...  118  0  118   85  14  123  2   96  10
# 4        1370.0    0    0    0  ...  181  0  161  104  12  137  8  157   0
#
#     11
# 0   62
# 1  121
# 2   39
# 3   58
# 4   61
#
# [5 rows x 54 columns]

# %%
# normalize

pc_counts = tp3c.loc[:,[k for k in range(12)]]
pc_freqs = pc_counts.div(pc_counts.sum(axis=1), axis=0)

# %%
Z = np.zeros((12,12))

for k in range(1,13):
    for j in range(k):
        Z[k-1, j] += 1/k

# reorder in fifths
Z = Z[:,[k *7 % 12 for k in range(12)]]

# %%
# add uniform fifths series

# pc_freqs = pc_freqs.append(pd.DataFrame(Z), ignore_index=True) # old pandas version
pc_freqs = pd.concat([pc_freqs,pd.DataFrame(Z)], ignore_index=True)

# %%
pc_freqs.tail()
# Out:
#              0         1         2         3         4         5         6  \
# 2019  0.125000  0.125000  0.125000  0.000000  0.125000  0.000000  0.125000
# 2020  0.111111  0.111111  0.111111  0.000000  0.111111  0.000000  0.111111
# 2021  0.100000  0.100000  0.100000  0.100000  0.100000  0.000000  0.100000
# 2022  0.090909  0.090909  0.090909  0.090909  0.090909  0.000000  0.090909
# 2023  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333
#
#              7         8         9        10        11
# 2019  0.125000  0.000000  0.125000  0.000000  0.125000
# 2020  0.111111  0.111111  0.111111  0.000000  0.111111
# 2021  0.100000  0.100000  0.100000  0.000000  0.100000
# 2022  0.090909  0.090909  0.090909  0.090909  0.090909
# 2023  0.083333  0.083333  0.083333  0.083333  0.083333

# %% [markdown]
# ## Examples

# %%
exs = {
    "Machaut" : 8,
    "Lasso" : 253,
    "Gesualdo" : 325,
    "Bach" : 637,
    "Mozart" : 826,
    "Beethoven" : 932,
    "Schubert" : 1343,
#     "Hensel" : 1465,
    "Liszt" : 1658,
    "Mahler" : 1890,
    "Debussy" : 1975,
    "Scriabin" : 1978,
#     "Vaughan Williams" : 2000,
    "Webern" : 2005
}

# %%
fig, axes = plt.subplots(4,3, figsize=(12,9), sharey=True)

axes = axes.flatten()

for i, (ax, k) in enumerate(zip(axes, exs.keys())):
    piece = pc_freqs.loc[exs[k],[n for n in range(12)]]
    piece = piece.div(piece.sum()) # normalize
    piece.plot(kind="bar", ax=ax, rot=0)
    ax.set_title(k)
    ax.set_ylim(0,0.275)
plt.tight_layout()
plt.savefig("img/pc_distribusions.png", dpi=DPI)
plt.show()

# %% [markdown]
# **Machaut, Dame, ce vous n'aperceu**

# %%
fig = plot_both_areas(8, data=pc_freqs)
plt.savefig("img/machaut.png", dpi=DPI)

# %% [markdown]
# **Orlando di Lasso**

# %%
fig = plot_both_areas(253, data=pc_freqs)
plt.savefig("img/lasso.png", dpi=300)

# %% [markdown]
# **Gesualdo**

# %%
fig = plot_both_areas(352, data=pc_freqs)
plt.savefig("img/gesualdo.png", dpi=300)

# %% [markdown]
# **Bach C major Prelude**

# %%
fig = plot_both_areas(637, data=pc_freqs)
plt.savefig("img/bach.png", dpi=300)

# %% [markdown]
# **Mozart, KV 333/1**

# %%
fig = plot_both_areas(826, data=pc_freqs)
plt.savefig("img/mozart.png", dpi=300)

# %% [markdown]
# **Beethoven op 2 no 1 mov 1**

# %%
fig = plot_both_areas(932, data=pc_freqs)
plt.savefig("img/beethoven.png", dpi=300)

# %% [markdown]
# **Schubert**

# %%
fig = plot_both_areas(1343, data=pc_freqs)
plt.savefig("img/schubert.png", dpi=300)

# %% [markdown]
# **Hensel**

# %%
fig = plot_both_areas(1465, data=pc_freqs)
plt.savefig("img/hensel.png", dpi=300)

# %% [markdown]
# **Liszt, Nuages gris**

# %%
fig = plot_both_areas(1658, data=pc_freqs)
plt.savefig("img/liszt.png", dpi=300)

# %% [markdown]
# **Mahler**

# %%
fig = plot_both_areas(1890, data=pc_freqs)
plt.savefig("img/mahler.png", dpi=300)

# %% [markdown]
# **Debussy Prelude The girl with the flaxen hair**

# %%
fig = plot_both_areas(1975, data=pc_freqs)
plt.savefig("img/debussy.png", dpi=300)

# %% [markdown]
# **Scriabin, op. 74, 1**

# %%
scriabin = plot_both_areas(1978, data=pc_freqs)
plt.savefig("img/scriabin.png", dpi=300)

# %% [markdown]
# **Vaughan Williams, Motion and Stillness**

# %%
fig = plot_both_areas(2000, data=pc_freqs)
plt.savefig("img/vaughan_williams.png", dpi=300)

# %% [markdown]
# **Webern, op 27, 1**

# %%
fig = plot_both_areas(2005, data=pc_freqs)
plt.savefig("img/webern.png", dpi=300)

# %% [markdown]
# ## Series of fifths

# %%
for i in range(2013, 2024):
    plot_both_areas(i, data=pc_freqs)

# %%
# values = [1/12] * 12
# angles = [n / float(12) * 2 * np.pi for n in range(12)]

# P = Polygon(zip(values * np.cos(angles), values * np.sin(angles)))
# A_max = P.area
# print(P.area)
# P

# %%
# def area(n):
#     """Area of regular polygon where the axes sum to 1."""
#     return np.sin(2 * np.pi / n) / (2 * n)

# %%
# fig, ax = plt.subplots()

# xxx = np.linspace(3,12.)
# ax.plot(xxx, area(xxx))
# ax.scatter([k for k in range(3,13)], vals, marker="o")
# ax.text(6, 1/10, "$A(k)=\\frac{sin(2\pi/k)}{2k}$", fontsize=16)

# plt.show()

# %%
# # from matplotlib.patches import RegularPolygon

# fig, axes = plt.subplots(2, 5, figsize=(12,5), sharex=True, sharey=True)

# axes = axes.flatten()

# for i, ax in enumerate(axes):
#     n = i + 3
#     ax.set_aspect("equal")
#     ext = .35
#     ax.set_xlim(-ext,ext)
#     ax.set_ylim(-ext,ext)
#     xxx = np.linspace(-ext,ext, 100)
#     zeros = np.zeros(100)
#     ax.plot(xxx, zeros, c="gray", lw=1)
#     ax.plot(zeros, xxx, c="gray", lw=1)
#     ax.set_title(f"A(n): {round(area(n),3)}")
    
#     pp = RegularPolygon((0,0), n, 1/n, edgecolor="k", facecolor="w")
#     axes[n-3].add_patch(pp)

# plt.tight_layout()
# plt.show()'

# %%
# _, _, P = get_polygon([1/12]*12, ordering="fifths")
# P

# %%
calculate_features(pc_freqs)
pc_freqs
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.162162  0.000000  0.143361  0.000000  0.121034  0.186839  0.000000
# 1     0.127501  0.001144  0.073185  0.000000  0.082905  0.164666  0.001144
# 2     0.122310  0.001133  0.105323  0.000000  0.125708  0.171008  0.003398
# 3     0.120833  0.012500  0.163889  0.000000  0.163889  0.118056  0.019444
# 4     0.082519  0.026059  0.196526  0.000000  0.174810  0.112921  0.013029
# ...        ...       ...       ...       ...       ...       ...       ...
# 2019  0.125000  0.125000  0.125000  0.000000  0.125000  0.000000  0.125000
# 2020  0.111111  0.111111  0.111111  0.000000  0.111111  0.000000  0.111111
# 2021  0.100000  0.100000  0.100000  0.100000  0.100000  0.000000  0.100000
# 2022  0.090909  0.090909  0.090909  0.090909  0.090909  0.000000  0.090909
# 2023  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333
#
# ...

# %%
pd.concat([pc_freqs, tp3c["display_year"]], axis=1).iloc[:2012,:][["chromatic_A", "fifths_A", "entropy", "display_year"]].to_csv("data/tp3c_features.csv", index=False)

# %%
# from scipy.stats import entropy

# pc_freqs["chromatic_A"] = pc_freqs.loc[:,[k for k in range(12)]].apply(lambda x: chromatic_area(x), axis=1)
# pc_freqs["fifths_A"] = pc_freqs.loc[:,[k for k in range(12)]].apply(lambda x: fifths_area(x), axis=1)
# pc_freqs["entropy"] = pc_freqs.loc[:,[k for k in range(12)]].apply(lambda x: entropy(x), axis=1)

# %%
uniform = get_polygon([1/12]*12)[2].area

# %%
x = pc_freqs.iloc[:-12,:].chromatic_A
y = pc_freqs.iloc[:-12,:].fifths_A

fig, ax = plt.subplots(figsize=(15,6))
ax.set_aspect('equal', 'box')

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(x, y, 1)
ax.plot(x, b + m * x, '-', c="gray", label=f"r={round(m, 2)}",zorder=-3)

sc = ax.scatter(
    x, 
    y, 
    alpha=.5, 
    marker=".", 
    c=tp3c["display_year"],#pc_freqs.iloc[:-12,:].entropy, 
    cmap="magma"
)

ax.set_xlabel("Chromaticism", fontsize=14)
ax.set_ylabel("Diatonicism", fontsize=14)

for key, value in exs.items():
    row = pc_freqs.loc[value, :]
    composer = key
    x_label = row["chromatic_A"]
    y_label = row["fifths_A"]
    ax.text(x_label, y_label, composer)
    ax.scatter(x_label, y_label, marker="x", c="k")

ax.scatter(uniform, uniform, c="w", edgecolors="k")

# artificial scales
# for i in range(pc_freqs.shape[0]-12,pc_freqs.shape[0]):
#     xx = pc_freqs.loc[i,:]["chromatic_A"]
#     yy = pc_freqs.loc[i,:]["fifths_A"]
#     ax.scatter(xx, yy)
#     ax.text(xx,yy,i-2011)
    
# "atypical"
# for idx in [325, 1466]:
#     row = tp3c.loc[idx, :]
#     composer = row["composer"]
#     x_label = row["chromatic_A"]
#     y_label = row["fifths_A"]
#     ax.text(x_label, y_label, composer, c="green", size=12)
#     ax.scatter(x_label, y_label, marker="x", c="green")
ax.legend()
plt.colorbar(sc)
plt.tight_layout()
plt.savefig("img/diatonicismVsChromaticism.png", dpi=300)
plt.show()

# %%
# sns.lmplot(data=tp3c, x="display_year", y="entropy")

# %% [markdown]
# ## ClassicalArchives MIDI

# %%
ca_midi = pd.read_csv("data/pitch_class_distributions.csv") # Classical Archives data
ca_midi.columns = ["year", "root", "mode"] + [k for k in range(12)]
ca_midi.to_csv("data/ca_midi.csv", index=False)

# ca_midi = pd.read_csv("data/ca_midi.csv")

# %%
ca_midi["chromatic_A"] = ca_midi.loc[:,[k for k in range(12)]].apply(lambda x: chromatic_area(x), axis=1)
ca_midi["fifths_A"] = ca_midi.loc[:,[k for k in range(12)]].apply(lambda x: fifths_area(x), axis=1)
ca_midi["entropy"] = ca_midi.loc[:,[k for k in range(12)]].apply(lambda x: entropy(x), axis=1)

# %%
ca_midi
# Out:
#          year  root   mode         0         1         2         3         4  \
# 0      1556.0   NaN    NaN  0.062929  0.000000  0.268307  0.000000  0.054920
# 1      1556.0   NaN    NaN  0.082086  0.000000  0.248460  0.000880  0.060739
# 2      1556.0   NaN    NaN  0.102664  0.000000  0.237204  0.008680  0.058066
# 3      1556.0   NaN    NaN  0.088041  0.000000  0.242680  0.000000  0.084742
# 4      1556.0   NaN    NaN  0.088940  0.000000  0.269099  0.000000  0.066135
# ...       ...   ...    ...       ...       ...       ...       ...       ...
# 13397  1765.0   4.0  minor  0.002601  0.071014  0.001301  0.099003  0.188306
# 13398  1765.0   4.0  minor  0.040369  0.075583  0.036297  0.082345  0.164422
# 13399  1770.0  10.0  major  0.126588  0.000000  0.140385  0.079302  0.040205
# 13400  1770.0  10.0  major  0.053980  0.010045  0.096024  0.181864  0.016333
# 13401  1770.0  10.0  major  0.107916  0.000000  0.117227  0.097251  0.015672
#
# ...

# %%
x = ca_midi.chromatic_A
y = ca_midi.fifths_A

fig, ax = plt.subplots(figsize=(8,6))

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(x, y, 1)
ax.plot(x, b + m * x, '-', c="gray", label=f"r={round(m, 2)}",zorder=-3)
ax.legend()

# ax.set_aspect("equal")
# ax.set_facecolor("black")
ax.scatter(x, y, alpha=.5, marker=".", c=ca_midi.entropy, cmap="magma")

ax.set_xlabel("Chromaticism")
ax.set_ylabel("Diatonicism")

# "typical"
# for idx in [8, 826, 637, 1658, 1978, 2005, 1890, 932, 1343, 253, 914, 1149]:
#     row = data.loc[idx, :]
#     composer = row["composer"]
#     x_label = row["chromatic_A"]
#     y_label = row["fifths_A"]
#     ax.text(x_label, y_label, composer)
#     ax.scatter(x_label, y_label, marker="x", c="k")
    
# "atypical"
# for idx in [325, 1466]:
#     row = data.loc[idx, :]
#     composer = row["composer"]
#     x_label = row["chromatic_A"]
#     y_label = row["fifths_A"]
#     ax.text(x_label, y_label, composer, c="green", size=12)
#     ax.scatter(x_label, y_label, marker="x", c="green")
    
plt.show()

# %% [markdown]
# ## Pop MIDI

# %% [markdown]
# https://colinraffel.com/projects/lmd/

# %%
# import pretty_midi
# midi_folder ="data/lmd_matched"#  "clean_midi" #

# %%
# import os
# cpt = sum([len(files) for r, d, files in os.walk(midi_folder)])
# print(cpt)

# %%
# %%time

# import glob
# import tqdm

# files = glob.glob(midi_folder + '/**/*.mid', recursive=True)

# s_list = []

# for f in tqdm.tqdm(files):
#     try:
#         midi_data = pretty_midi.PrettyMIDI(f)
        
#         midi_list = []
#         for instrument in midi_data.instruments:
#             for note in instrument.notes:
#                 start = note.start
#                 end = note.end
#                 pitch = note.pitch
#                 velocity = note.velocity
#                 midi_list.append([start, end, pitch, velocity, instrument.name])
        
#         midi_list = sorted(midi_list, key=lambda x: (x[0], x[2]))
#         midi_df = pd.DataFrame(midi_list, columns=['Start', 'End', 'Pitch', 'Velocity', 'Instrument'])
#         midi_df["Duration"] = midi_df.End - midi_df.Start
#         midi_df["PC"] = midi_df["Pitch"] % 12
#         total = midi_df.groupby("PC")["Duration"].sum().sum()
#         s = midi_df.groupby("PC")["Duration"].sum() / total
#         s_list.append(s)
        
#     except:
#         pass

# %%
# midi_df = pd.DataFrame(s_list).reset_index(drop=True).fillna(0.)
# midi_df

# %%
# midi_df["chromatic_A"] = midi_df.loc[:,[k for k in range(12)]].apply(lambda x: chromatic_area(x), axis=1)
# midi_df["fifths_A"] = midi_df.loc[:,[k for k in range(12)]].apply(lambda x: fifths_area(x), axis=1)
# midi_df["entropy"] = midi_df.loc[:,[k for k in range(12)]].apply(lambda x: entropy(x), axis=1)

# %%
# midi_df.to_csv("data/lmd_matched.csv", index=False)
midi_df = pd.read_csv("data/lmd_matched.csv")

# %%
midi_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.080036  0.011494  0.333972  0.013596  0.059851  0.000981  0.073728
# 1  0.138729  0.006928  0.104624  0.023771  0.178267  0.070031  0.028202
# 2  0.000111  0.212203  0.016107  0.029589  0.271868  0.000064  0.078908
# 3  0.000112  0.212168  0.016366  0.028953  0.273002  0.000063  0.078639
# 4  0.000111  0.211565  0.016053  0.029489  0.273382  0.000064  0.078652
#
#           7         8         9        10        11  chromatic_A  fifths_A  \
# 0  0.179204  0.000280  0.135145  0.020605  0.091109     0.008875  0.035205
# 1  0.090369  0.069369  0.170904  0.005150  0.113655     0.015194  0.026582
# 2  0.003957  0.132839  0.130619  0.023220  0.100514     0.008888  0.030622
# 3  0.003953  0.132372  0.130319  0.023236  0.100817     0.008841  0.030626
# 4  0.003943  0.132391  0.130205  0.023142  0.101003     0.008852  0.030636
#
#     entropy
# 0  1.924840
# 1  2.206334
# 2  1.929939
# 3  1.928673
# 4  1.928689

# %%
# calculate_features(midi_df)

# %%
midi_df.shape
# Out:
# (115195, 15)

# %%
x = midi_df.chromatic_A
y = midi_df.fifths_A

fig, ax = plt.subplots(figsize=(8,6))

from numpy.polynomial.polynomial import polyfit
b, m = polyfit(x, y, 1)
ax.plot(x, b + m * x, '-', c="gray", label=f"r={round(m, 2)}",zorder=-3)
ax.legend()

# ax.set_aspect("equal")
# ax.set_facecolor("black")
ax.scatter(x, y, alpha=.5, marker=".", c=midi_df.entropy, cmap="magma")

ax.set_xlabel("Chromaticism")
ax.set_ylabel("Diatonicism")

# "typical"
# for idx in [8, 826, 637, 1658, 1978, 2005, 1890, 932, 1343, 253, 914, 1149]:
#     row = data.loc[idx, :]
#     composer = row["composer"]
#     x_label = row["chromatic_A"]
#     y_label = row["fifths_A"]
#     ax.text(x_label, y_label, composer)
#     ax.scatter(x_label, y_label, marker="x", c="k")
    
# "atypical"
# for idx in [325, 1466]:
#     row = data.loc[idx, :]
#     composer = row["composer"]
#     x_label = row["chromatic_A"]
#     y_label = row["fifths_A"]
#     ax.text(x_label, y_label, composer, c="green", size=12)
#     ax.scatter(x_label, y_label, marker="x", c="green")
    
plt.show()

# %%
major = (get_polygon(templates.loc[2,pcs()].values, ordering="chromatic")[2].area, get_polygon(templates.loc[2,pcs()].values, ordering="fifths")[2].area)
minor = (get_polygon(templates.loc[3,pcs()].values, ordering="chromatic")[2].area, get_polygon(templates.loc[3,pcs()].values, ordering="fifths")[2].area)

# %% [markdown]
# ## Random

# %%
# random_df = pd.DataFrame(np.random.dirichlet(np.ones(12), size=10_000), columns=[k for k in range(12)])
# random_df["chromatic_A"] = random_df.loc[:,[k for k in range(12)]].apply(lambda x: chromatic_area(x), axis=1)
# random_df["fifths_A"] = random_df.loc[:,[k for k in range(12)]].apply(lambda x: fifths_area(x), axis=1)
# random_df["entropy"] = random_df.loc[:,[k for k in range(12)]].apply(lambda x: entropy(x), axis=1)

# random_df.to_csv("data/random.csv", index=False)
random_df = pd.read_csv("data/random.csv")

# %% [markdown]
# ## Comparison

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10), sharey=True)

axes = axes.flatten()

from numpy.polynomial.polynomial import polyfit

for i, (df, lab) in enumerate(zip([pc_freqs, ca_midi, midi_df, random_df], ["TP3C", "ClassicalArchives MIDI", "Lakh MIDI", "Random"])): 
    
    x = df.chromatic_A
    y = df.fifths_A
    
#     if i < 3:
    b, m = polyfit(x, y, 1)
    axes[i].plot(x, b + m * x, '-', c="gray", label=f"r={round(m, 2)}",zorder=-3)
    
    ax.set_aspect("equal")
    # ax.set_facecolor("black")
    axes[i].scatter(x, y, alpha=.2, marker=".", c=df.entropy, cmap="magma") # , 

    axes[i].set_xlabel("Chromaticism", fontsize=14)
    axes[i].set_title(lab + f" (n={df.shape[0]})")
    
    axes[i].scatter(uniform, uniform, c="w", s=50, edgecolors="k", zorder=3, label="uniform")
    axes[i].scatter(major[0], major[1], c="g", s=50, edgecolors="k", zorder=3, label="major")
    axes[i].scatter(minor[0], minor[1], c="b", s=50, edgecolors="k", zorder=3, label="minor")
    
#     x_ = np.arange(0,1/16, 0.01)
#     y_ = x_
#     axes[i].plot(x_, y_, "--", c="gray", lw=1, zorder=-4)
    
#     y__ = 1/16 - x_
#     axes[i].plot(x_, y__, "--", c="gray", lw=1, zorder=-4)
    
    axes[i].set_xlim(0, 1/16)
    
    axes[i].legend()
    
    

axes[0].set_ylabel("Diatonicism", fontsize=14)    

# axes[0].fill_between(y_fill, x_fill, c="g")

# xx = np.linspace(0, 1/16, 1000)
# yy = 1/16 -xx
# axes[3].plot(xx, yy, c="k", ls="--")
# axes[3].text(1.1/32,1/32, "$f(x)=\\frac{1}{16}-x$", size=14)

plt.tight_layout()
plt.savefig("img/comparison_datasets.png", dpi=300)
plt.show()

# %%
data[data.fifths_A < 0.018]
# Out:
#         composer composer_first opus   no  mov  \
# 1183    Schubert          Franz  NaN   11  NaN
# 1667       Liszt          Franz  206  NaN  NaN
# 1968  Schoenberg         Arnold   19    2  NaN
# 1973    Scriabin      Alexander   67    1  NaN
#
#                                 title  display_year  Fbb  Cbb  Gbb  ...   5  \
# 1183                        Die Stadt        1828.0    0    0    0  ...  41
# 1667  Trauervorspiel und Trauermarsch        1885.0    0    0    0  ...  82
# 1968                              NaN        1911.0    0    0    0  ...   4
# 1973                       2 Preludes        1913.0    0    0    0  ...  12
#
#         6    7   8    9   10  11  chromatic_A  fifths_A   entropy
# 1183   75   66  33  123    5  15     0.007653  0.016732  1.751068
# 1667  210  255  32  103  294  51     0.014948  0.017408  2.155307
# 1968    6   29   2    3    3  31     0.016628  0.017157  1.978231
# 1973   64   67  17   37   54   8     0.017620  0.017458  2.294563
#
# ...

# %%
fig, axes = plt.subplots(1,2, figsize=(10,6), subplot_kw={"polar": True})
plot_area(1667, ordering="chromatic", ax=axes[0], fill=True)
plot_area(1667, ordering="fifths", ax=axes[1], fill=True)
# plt.savefig("piece.png")
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,6), subplot_kw={"polar": True})
plot_area(1968, ordering="chromatic", ax=axes[0], fill=True)
plot_area(1968, ordering="fifths", ax=axes[1], fill=True)
# plt.savefig("piece.png")
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,6), subplot_kw={"polar": True})
plot_area(1973, ordering="chromatic", ax=axes[0], fill=True)
plot_area(1973, ordering="fifths", ax=axes[1], fill=True)
# plt.savefig("piece.png")
plt.show()

# %%
data[(data.chromatic_A < 0.01) & (data.fifths_A <0.02)]
# Out:
#       composer composer_first opus  no  mov      title  display_year  Fbb  \
# 1183  Schubert          Franz  NaN  11  NaN  Die Stadt        1828.0    0
#
#       Cbb  Gbb  ...  4   5   6   7   8    9  10  11  chromatic_A  fifths_A
# 1183    0    0  ...  3  41  75  66  33  123   5  15     0.007653  0.016732
#
# [1 rows x 56 columns]

# %%
data[(data.chromatic_A > 0.01) & (data.fifths_A > 0.04)]
# Out:
#        composer composer_first opus no  mov                    title  \
# 1034  Reichardt         Louise  NaN  5  NaN  Für die Laute componirt
#
#       display_year  Fbb  Cbb  Gbb  ...  4   5  6  7  8  9  10  11  \
# 1034        1802.5    0    0    0  ...  0  33  0  0  0  8  40   2
#
#       chromatic_A  fifths_A
# 1034     0.010661  0.040124
#
# [1 rows x 56 columns]

# %%
data[data.chromatic_A > 0.0225]
# Out:
#      composer composer_first opus no  mov          title  display_year  Fbb  \
# 1699     Wolf           Hugo  NaN  6  NaN  Der Soldat II        1889.0    0
#
#       Cbb  Gbb  ...   4   5   6    7    8   9  10  11  chromatic_A  fifths_A
# 1699    0    0  ...  11  50  79  137  109  13  38  79       0.0234  0.019945
#
# [1 rows x 56 columns]

# %%
data.loc[1183, 0:11]
# Out:
# 0     422
# 1       3
# 2      22
# 3     100
# 4       3
# 5      41
# 6      75
# 7      66
# 8      33
# 9     123
# 10      5
# 11     15
# Name: 1183, dtype: object

# %%
fig, axes = plt.subplots(1,2, figsize=(10,6), subplot_kw={"polar": True})
plot_area(1699, ordering="chromatic", ax=axes[0], fill=True)
plot_area(1699, ordering="fifths", ax=axes[1], fill=True)
# plt.savefig("piece.png")
plt.show()

# %%
pc_freqs["ratio"] = pc_freqs["chromatic_A"] / pc_freqs["fifths_A"]

# %%
pc_freqs["sum"] = pc_freqs["chromatic_A"] + pc_freqs["fifths_A"]

# %%
pc_freqs["diff"] = pc_freqs["chromatic_A"] - pc_freqs["fifths_A"]

# %%
data["ratio"].plot(kind="kde");

# %%
data["sum"].plot(kind="kde")
plt.xlim(0.03,0.05);

# %%
data["diff"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
years = 25

# %%
data = data.sort_values(by="display_year").reset_index(drop=True)

# %%
data[["chromatic_A", "fifths_A"]].ewm(span=years).mean().plot(figsize=(20,3), title="Smoothed areas");

# %%
pc_freqs["ratio"].ewm(span=years).mean().plot(figsize=(12,6), lw=3, color="teal", title="Ratio between chromatic and fifths areas");

# %% [markdown]
# ### Aggregated by years

# %%
tp3c.groupby("display_year")["chromatic_A"].mean().plot()
tp3c.groupby("display_year")["fifths_A"].mean().plot()
# Out:
# <AxesSubplot:xlabel='display_year'>

# %%
kws = {
    "figsize" : (12, 6),
    "lw" : 3
}

# %%
agg = data.sort_values("display_year").reset_index(drop=True).groupby("display_year")["ratio"].mean().ewm(span=30).mean().plot(**kws, color="firebrick", ylabel="chromatic / fifths ratio");

# %%
agg = data.sort_values("display_year").reset_index(drop=True).groupby("display_year")["sum"].mean().ewm(span=years).mean().plot(**kws, color="teal")

# %%
data.sort_values(by="ratio", ascending=False)[:12]
# Out:
#       composer    composer_first opus   no  mov                         title  \
# 1685      Wolf              Hugo  NaN    6  NaN                 Der Soldat II
# 1870  Scriabin         Alexander   39    2  NaN                    4 Preludes
# 1658     Liszt             Franz  199  NaN  NaN                   Nuages gris
# 1884  Scriabin         Alexander   39    3  NaN                    4 Preludes
# 1518     Alkan  Charles Valentin  38b    2  NaN               Chant de Guerre
# 1963     Ravel           Maurice   55    3  NaN                        Scarbo
# 1973  Scriabin         Alexander   67    1  NaN                    2 Preludes
# 1883  Scriabin         Alexander   39    4  NaN                    4 Preludes
# 2005    Webern             Anton   27    1  NaN                           NaN
# 1110  Schubert             Franz  NaN  NaN  NaN                           NaN
# 1961  Granados           Enrique   11    5  NaN  El Amor y la muerte (balada)
# ...
